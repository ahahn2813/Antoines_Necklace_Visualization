# %%
from Antoines_NecklaceClass import AntoineNecklace

# %%
necklace = AntoineNecklace(N_l1=14, N_l2=14)
necklace.mesh_res = 20
necklace.file_name = "level_2_14_and_14.png"
necklace.generate_level_two(parent_l2_C=25)
necklace.mesh_res = 50
necklace.file_name = "level_1_14.png"
necklace.generate_level_one(parent_l1_C=15)
necklace.mesh_res = 100
necklace.file_name = "level_0.png"
necklace.eye = [1.5,1.5,1.8]
necklace.generate_level_zero(parent_l0_C=5)
# Out:
# Writing to file...
# Image saved successfully!
# Writing to file...
# Image saved successfully!
# Writing to file...
# Image saved successfully!

# %%
necklace1 = AntoineNecklace(N_l1=16, N_l2=16)
necklace1.mesh_res = 20
necklace1.opacity = 1.0
necklace1.eye = [1.25,1.25,1.63]
necklace1.file_name = "level_2_16_and_16.png"
necklace1.generate_level_two(parent_l2_C=30)
necklace1.mesh_res = 50
necklace1.file_name = "level_1_16.png"
necklace1.generate_level_one(parent_l1_C=15)
necklace1.mesh_res = 100
necklace1.eye = [1.5,1.5,1.8]
necklace1.file_name = "level_0.png"
necklace1.generate_level_zero(parent_l0_C=5)
# Out:
# Writing to file...
# Image saved successfully!
# Writing to file...
# Image saved successfully!
# Writing to file...
# Image saved successfully!
