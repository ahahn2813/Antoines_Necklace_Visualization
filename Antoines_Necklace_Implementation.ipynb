# %% [markdown]
# # Antoine's Necklace Implementation

# %%
#import class
from Antoines_NecklaceClass import AntoineNecklace

# %% [markdown]
# ## Instantiation
#
# We construct an instance with the settings $14$ in level 1, $14$ in level 2, and $10$ in level 3.

# %%
necklace = AntoineNecklace(N_l1=14, N_l2=14, N_l3=10)

# %% [markdown]
# ## Level 0

# %%
necklace.mesh_res = 100 #increase resolution for higher accuracy
necklace.file_name = "figures/level_0.png"
necklace.eye = [1.5,1.5,1.8]
necklace.generate_level_zero(parent_l0_C=5) #generate torus with radius set to 5
# Out:
# Writing to file...
# Image saved successfully!

# %% [markdown]
# ## Level 1

# %%
necklace.mesh_res = 50 # reduce resolution to decrease compute time
necklace.file_name = "figures/level_1_14_smaller5.png"
necklace.eye = [1,1,1.3]
necklace.generate_level_one(parent_l1_C=10) #generate level 1 with large torus radius at 15
# Out:
# Writing to file...
# Image saved successfully!

# %% [markdown]
# ## Level 2

# %%
necklace.mesh_res = 12 # reduce resolution to decrease compute time
necklace.scale = 1
necklace.file_name = "figures/level_2_14_and_14_8.png"
necklace.eye = [1.1,1.1,1.4]
necklace.generate_level_two(parent_l2_C=5)
# Out:
# Writing to file...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 necklace.file_name = "figures/level_2_14_and_14_8.png"
#       4 necklace.eye = [1.1,1.1,1.4]
# ----> 5 necklace.generate_level_two(parent_l2_C=5)
#
# File ~/Documents/GitHub/Antoines_Necklace_Visualization/Antoines_NecklaceClass.py:312, in AntoineNecklace.generate_level_two(self, parent_l2_C)
#     310 def generate_level_two(self, parent_l2_C):
#     311     fig = self.get_level_two_necklace_tori(parent_l2_C)
# --> 312     self.get_figure(fig)
#
# File ~/Documents/GitHub/Antoines_Necklace_Visualization/Antoines_NecklaceClass.py:283, in AntoineNecklace.get_figure(self, fig)
#     281 svg_file_name = self.file_name
#     282 # 2. Update the write line to target the SVG file and specify the kaleido engine
# --> 283 fig.write_image(svg_file_name, engine="orca", scale = self.scale)
#     284 print("Image saved successfully!")
#     285 if self.html == True:
#
# File /opt/anaconda3/lib/python3.12/site-packages/plotly/basedatatypes.py:3835, in BaseFigure.write_image(self, *args, **kwargs)
#    3775 """
#    3776 Convert a figure to a static image and write it to a file or writeable
#    3777 object
#    (...)
#    3831 None
#    3832 """
#    3833 import plotly.io as pio
# -> 3835 return pio.write_image(self, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/plotly/io/_kaleido.py:266, in write_image(fig, file, format, scale, width, height, validate, engine)
#     250             raise ValueError(
#     251                 """
#     252 Cannot infer image type from output path '{file}'.
#    (...)
#     260                 )
#     261             )
#     263     # Request image
#     264     # -------------
#     265     # Do this first so we don't create a file if image conversion fails
# --> 266     img_data = to_image(
#     267         fig,
#     268         format=format,
#     269         scale=scale,
#     270         width=width,
#     271         height=height,
#     272         validate=validate,
#     273         engine=engine,
#     274     )
#     276     # Open file
#     277     # ---------
#     278     if path is None:
#     279         # We previously failed to make sense of `file` as a pathlib object.
#     280         # Attempt to write to `file` as an open file descriptor.
#
# File /opt/anaconda3/lib/python3.12/site-packages/plotly/io/_kaleido.py:115, in to_image(fig, format, width, height, scale, validate, engine)
#     111 if engine == "orca":
#     112     # Fall back to legacy orca image export path
#     113     from ._orca import to_image as to_image_orca
# --> 115     return to_image_orca(
#     116         fig,
#     117         format=format,
#     118         width=width,
#     119         height=height,
#     120         scale=scale,
#     121         validate=validate,
#     122     )
#     123 elif engine != "kaleido":
#     124     raise ValueError(
#     125         "Invalid image export engine specified: {engine}".format(
#     126             engine=repr(engine)
#     127         )
#     128     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/plotly/io/_orca.py:1445, in to_image(fig, format, width, height, scale, validate)
#    1393 """
#    1394 Convert a figure to a static image bytes string
#    1395
#    (...)
#    1441     The image data
#    1442 """
#    1443 # Make sure orca sever is running
#    1444 # -------------------------------
# -> 1445 ensure_server()
#    1447 # Handle defaults
#    1448 # ---------------
#    1449 # Apply configuration defaults to unspecified arguments
#    1450 if format is None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/plotly/io/_orca.py:1296, in ensure_server()
#    1293 if not config.server_url:
#    1294     # Validate orca executable only if server_url is not provided
#    1295     if status.state == "unvalidated":
# -> 1296         validate_executable()
#    1297     # Acquire lock to make sure that we keep the properties of orca_state
#    1298     # consistent across threads
#    1299     with orca_lock:
#    1300         # Cancel the current shutdown timer, if any
#
# File /opt/anaconda3/lib/python3.12/site-packages/plotly/io/_orca.py:982, in validate_executable()
#     979     formatted_path = path.replace(os.pathsep, "\n    ")
#     981     if executable is None:
# --> 982         raise ValueError(
#     983             """
#     984 The orca executable is required to export figures as static images,
#     985 but it could not be found on the system path.
#     986
#     987 Searched for executable '{executable}' on the following path:
#     988     {formatted_path}
#     989
#     990 {instructions}""".format(
#     991                 executable=config.executable,
#     992                 formatted_path=formatted_path,
#     993                 instructions=install_location_instructions,
#     994             )
#     995         )
#     997     # Check if we should run with Xvfb
#     998     # --------------------------------
#     999     xvfb_args = [
#    1000         "--auto-servernum",
#    1001         "--server-args",
#    1002         "-screen 0 640x480x24 +extension RANDR +extension GLX",
#    1003         executable,
#    1004     ]
#
# ValueError:
# The orca executable is required to export figures as static images,
# but it could not be found on the system path.
#
# Searched for executable 'orca' on the following path:
#     /opt/anaconda3/bin
#     /opt/anaconda3/condabin
#     /opt/homebrew/bin
#     /opt/homebrew/sbin
#     /usr/local/bin
#     /System/Cryptexes/App/usr/bin
#     /usr/bin
#     /bin
#     /usr/sbin
#     /sbin
#     /var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin
#     /var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin
#     /var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin
#     /pkg/env/global/bin
#     /opt/X11/bin
#     /Library/Apple/usr/bin
#
# If you haven't installed orca yet, you can do so using conda as follows:
#
#     $ conda install -c plotly plotly-orca
#
# Alternatively, see other installation methods in the orca project README at
# https://github.com/plotly/orca
#
# After installation is complete, no further configuration should be needed.
#
# If you have installed orca, then for some reason plotly.py was unable to
# locate it. In this case, set the `plotly.io.orca.config.executable`
# property to the full path of your orca executable. For example:
#
#     >>> plotly.io.orca.config.executable = '/path/to/orca'
#
# After updating this executable property, try the export operation again.
# If it is successful then you may want to save this configuration so that it
# will be applied automatically in future sessions. You can do this as follows:
#
#     >>> plotly.io.orca.config.save()
#
# If you're still having trouble, feel free to ask for help on the forums at
# https://community.plot.ly/c/api/python

# %%
necklace.mesh_res = 12 # reduce resolution to decrease compute time and memory pressure
necklace.scale = 1
necklace.eye = [1.1,1.1,1.4]
necklace.file_name = "figures/level_2_14_and_14_3.png"
necklace.generate_level_two(parent_l2_C=35)
# Out:
# Writing to file...
# Image saved successfully!

# %% [markdown]
# ## Level 3

# %%
necklace.N_l1 = 14 #reduce number of tori in each level 1 to decrease compute time and memory pressure
necklace.N_l2 = 14 #reduce number of tori in each level 2 to decrease compute time and memory pressure
necklace.mesh_res = 5 # reduce resolution to decrease compute time and memory pressure
necklace.scale = 1
necklace.eye = [1.1,1.1,1.4]
necklace.file_name = "figures/level_3_14_14_and_14.png"
necklace.generate_level_three(parent_l3_C=40)
# Out:
# Writing to file...
# Image saved successfully!

# %%
necklace.N_l1 = 12 #reduce number of tori in each level 1 to decrease compute time and memory pressure
necklace.N_l2 = 14 #reduce number of tori in each level 2 to decrease compute time and memory pressure
necklace.N_l3 = 14
necklace.mesh_res = 5 # reduce resolution to decrease compute time and memory pressure
necklace.scale = 1
necklace.eye = [1.1,1.1,1.4]
necklace.file_name = "figures/level_3_12_14_and_14.png"
necklace.generate_level_three(parent_l3_C=50)
# Out:
# Writing to file...
# Image saved successfully!
